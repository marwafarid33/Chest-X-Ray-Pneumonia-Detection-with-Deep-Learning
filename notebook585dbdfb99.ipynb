# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import class_weight
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# ======================
# Paths
# ======================
base_dir = "/kaggle/input/chest-xray-pneumonia/chest_xray"
train_dir = os.path.join(base_dir, "train")
val_dir   = os.path.join(base_dir, "val")
test_dir  = os.path.join(base_dir, "test")

img_size = 150
batch_size = 32

# ======================
# Data Generators with stronger augmentation
# ======================
train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True,
    brightness_range=[0.8,1.2]
)

val_gen = ImageDataGenerator(rescale=1./255)
test_gen = ImageDataGenerator(rescale=1./255)

train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='binary',
    color_mode='grayscale'
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='binary',
    color_mode='grayscale'
)

test_data = test_gen.flow_from_directory(
    test_dir,
    target_size=(img_size, img_size),
    batch_size=1,
    shuffle=False,
    class_mode='binary',
    color_mode='grayscale'
)

# ======================
# Compute class weights
# ======================
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_data.classes),
    y=train_data.classes
)
class_weights = dict(enumerate(class_weights))

# ======================
# Build Deeper CNN Model
# ======================
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(img_size,img_size,1)),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(256, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Flatten(),
    Dropout(0.5),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

# ======================
# Callbacks
# ======================
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr  = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)

# ======================
# Training
# ======================
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=30,
    callbacks=[early_stop, reduce_lr],
    class_weight=class_weights
)

# ======================
# Evaluation
# ======================
loss, acc = model.evaluate(test_data)
print(f"✅ Test Accuracy: {acc*100:.2f}%")

# ======================
# Accuracy & Loss plots
# ======================
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='val')
plt.title("Accuracy")
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.title("Loss")
plt.legend()
plt.show()

# ======================
# Predictions + Confusion Matrix
# ======================
y_pred = model.predict(test_data)
y_pred = (y_pred > 0.5).astype(int)

cm = confusion_matrix(test_data.classes, y_pred)
plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt='d', cmap="Blues",
            xticklabels=["Normal","Pneumonia"],
            yticklabels=["Normal","Pneumonia"])
plt.title("Confusion Matrix")
plt.show()

print("\nClassification Report:\n")
print(classification_report(test_data.classes, y_pred, target_names=["Normal","Pneumonia"]))
# Out:
# 2025-10-25 17:50:28.522951: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761414628.695765      37 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761414628.753425      37 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1761414643.935757      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 148, 148, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 148, 148, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 72, 72, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 72, 72, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 34, 34, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 34, 34, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 17, 17, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 15, 15, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 15, 15, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 7, 7, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     3,211,520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,601,537 (13.74 MB)
#  Trainable params: 3,600,577 (13.74 MB)
#  Non-trainable params: 960 (3.75 KB)
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761414651.363488     117 service.cc:148] XLA service 0x7d8bec0025e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1761414651.364221     117 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1761414651.937037     117 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   1/163 ━━━━━━━━━━━━━━━━━━━━ 26:59 10s/step - accuracy: 0.4688 - loss: 1.2775
# I0000 00:00:1761414656.482685     117 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 73s 387ms/step - accuracy: 0.7492 - loss: 1.4741 - val_accuracy: 0.5000 - val_loss: 18.8272 - learning_rate: 0.0010
# Epoch 2/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 40s 243ms/step - accuracy: 0.8370 - loss: 0.3712 - val_accuracy: 0.5000 - val_loss: 52.5951 - learning_rate: 0.0010
# Epoch 3/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 39s 241ms/step - accuracy: 0.8658 - loss: 0.3219 - val_accuracy: 0.5625 - val_loss: 13.3440 - learning_rate: 0.0010
# Epoch 4/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 39s 242ms/step - accuracy: 0.8732 - loss: 0.2988 - val_accuracy: 0.6250 - val_loss: 0.7049 - learning_rate: 0.0010
# Epoch 5/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 39s 241ms/step - accuracy: 0.8767 - loss: 0.2888 - val_accuracy: 0.6875 - val_loss: 1.7028 - learning_rate: 0.0010
# Epoch 6/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 39s 239ms/step - accuracy: 0.8978 - loss: 0.2506 - val_accuracy: 0.5625 - val_loss: 13.5263 - learning_rate: 0.0010
# Epoch 7/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.8875 - loss: 0.2754
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 39s 239ms/step - accuracy: 0.8875 - loss: 0.2753 - val_accuracy: 0.5625 - val_loss: 1.4460 - learning_rate: 0.0010
# Epoch 8/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 39s 239ms/step - accuracy: 0.9131 - loss: 0.2236 - val_accuracy: 0.6250 - val_loss: 0.9694 - learning_rate: 5.0000e-04
# Epoch 9/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 39s 239ms/step - accuracy: 0.9170 - loss: 0.2033 - val_accuracy: 0.6875 - val_loss: 0.6320 - learning_rate: 5.0000e-04
# Epoch 10/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 39s 240ms/step - accuracy: 0.9153 - loss: 0.2023 - val_accuracy: 0.5625 - val_loss: 2.0447 - learning_rate: 5.0000e-04
# Epoch 11/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 39s 239ms/step - accuracy: 0.9343 - loss: 0.1803 - val_accuracy: 0.5000 - val_loss: 2.0286 - learning_rate: 5.0000e-04
# Epoch 12/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9260 - loss: 0.1883
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 39s 241ms/step - accuracy: 0.9260 - loss: 0.1883 - val_accuracy: 0.5000 - val_loss: 2.0934 - learning_rate: 5.0000e-04
# Epoch 13/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 40s 243ms/step - accuracy: 0.9397 - loss: 0.1597 - val_accuracy: 0.5625 - val_loss: 0.8530 - learning_rate: 2.5000e-04
# Epoch 14/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 39s 240ms/step - accuracy: 0.9379 - loss: 0.1778 - val_accuracy: 0.5000 - val_loss: 2.3976 - learning_rate: 2.5000e-04
# 624/624 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.8559 - loss: 0.4018
# ✅ Test Accuracy: 87.82%
# 624/624 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       Normal       0.86      0.80      0.83       234
#    Pneumonia       0.89      0.92      0.90       390
#
#     accuracy                           0.88       624
#    macro avg       0.87      0.86      0.87       624
# weighted avg       0.88      0.88      0.88       624
